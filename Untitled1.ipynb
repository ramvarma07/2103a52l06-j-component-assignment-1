# %% [markdown]
# <a href="https://colab.research.google.com/github/ramvarma07/2103a52l06-j-component-assignment-1/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
/content/garments_worker_productivity (1).csv
# Out:
#   File "<ipython-input-1-647850c50674>", line 1
#     content(/garments_worker_productivity, (1).csv)
#             ^
# SyntaxError: invalid syntax

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
data=pd.read_csv('/content/garments_worker_productivity (1).csv')

# %%
data
# Out:
#             date   quarter  department        day  team  \
# 0     01-01-2015  Quarter1      sweing   Thursday     8
# 1     01-01-2015  Quarter1  finishing    Thursday     1
# 2     01-01-2015  Quarter1      sweing   Thursday    11
# 3     01-01-2015  Quarter1      sweing   Thursday    12
# 4     01-01-2015  Quarter1      sweing   Thursday     6
# ...          ...       ...         ...        ...   ...
# 1192  03-11-2015  Quarter2   finishing  Wednesday    10
# 1193  03-11-2015  Quarter2   finishing  Wednesday     8
# 1194  03-11-2015  Quarter2   finishing  Wednesday     7
# 1195  03-11-2015  Quarter2   finishing  Wednesday     9
# 1196  03-11-2015  Quarter2   finishing  Wednesday     6
#
#       targeted_productivity    smv     wip  over_time  incentive  idle_time  \
# 0                      0.80  26.16  1108.0       7080         98        0.0
# 1                      0.75   3.94     NaN        960          0        0.0
# ...

# %%
y=data['actual_productivity']
from matplotlib import pyplot as pt

# %%
x1=data['date']
x1=x1.replace("01-01-2015","1")
pt.plot(x1,y)

# %%
x2=data['quarter']
x2=x2.replace("Quarter1","1")
x2=x2.replace("Quarter2","2")
x2=x2.replace("Quarter3","3")
x2=x2.replace("Quarter4","4")
x2=x2.replace("Quarter5","5")
pt.plot(x2,y)

# %%
x3=data['department']
pt.plot(x3,y)
x3=x3.replace("sweing",1)
x3=x3.replace("finishing",2)
x3=x3.replace("finishing ",3)

# %%
x4=data['day']
x4=x4.replace("Thursday","1")
x4=x4.replace("Saturday","2")
x4=x4.replace("Sunday","3")
x4=x4.replace("Monday","4")
x4=x4.replace("Tuesday","5")
x4=x4.replace("Wednesday","6")
pt.plot(x4,y)

# %%
x5=data['team']
pt.plot(x5,y)

# %%
x6=data['targeted_productivity']
pt.plot(x6,y)

# %%
x7=data['smv']
pt.plot(x7,y)

# %%
x8=data['wip']
pt.plot(x8,y)

# %%
x9=data['over_time']
pt.plot(x9,y)

# %%
x10=data['incentive']
pt.plot(x10,y)

# %%
x11=data['idle_time']
pt.plot(x11,y)

# %%
x12=data['idle_men']
pt.plot(x12,y)

# %%
x13=data['no_of_style_change']
pt.plot(x13,y)

# %%
x14=data['no_of_workers']
pt.plot(x14,y)
